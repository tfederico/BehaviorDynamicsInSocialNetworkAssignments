# %% [markdown]
# # Mining Twitter (Based on Chapter 2 of the book 'Mastering...')
#
# In this notebook you will learn the basic concepts of Twitter mining and will try to gather some data from Twitter. Follow the steps, and do the exercises in a copy of this notebook. For that, click in *File -> Make a copy...* button. Don't forget to rename it.
#
# To include a new cell in the notebook, click on the plus sign on the toolbar, or tipe *Alt+Enter* to execute the current cell and create a new one. You can also click on the *Cell* menu.
#
# ## Important
# You have to run all the commands of this document, and make sure that they were executed well. After you finish, you have to save it as PDF and submit. Click in File -> Download as -> PDF via Latex to do so.
#
# **If you don't have Latex at your computer**, simply use File -> Print Preview and generate the PDF from there.

# %% [markdown]
# ## Installing libraries
# If one of the libraries is missing, go to Anaconda, at the Environments tab on the left side of the window and find and install your library.
#
# ![Anaconda](./Pic16.png)

# %% [markdown]
# ## Tweepy, Json and Python
#
# To collect data and make it readable, two libraries will be used. Tweepy is a library that embed the twitter API functions making it easier to interact with the Twitter server.
#
# Json is the format that the data is extracted from Twitter. For this reason, the library Json is also important.

# %% [markdown]
# ## Create your own key at Twitter webpage
# You need your own keys to have access to Twitter API. For that, go to https://apps.twitter.com/ then create a new App, and generate the keys.
#
# In case you have problems, watch the 5 first minutes of https://www.youtube.com/watch?v=pUUxmvvl2FE only. It is more than enough for this task.

# %% [markdown]
# ## Put your keys here!
#
# The variables where you should put your keys are below. So copy and paste all the 4 keys and paste them below.
#
# The first part of this notebook shows you the Tweepy library being loaded, together with the os and sys libraries. Those are used to check files at your system and yield system messages in case it is necessary.
#
# The two functions basically will read your tokens and keys and generate an object that can communicate with Twitter and ask for data. Don't be scared at first moment! Those functions are default for all twitter applications, and are very ugly, indeed.

# %%
import os
import sys
from tweepy import API
from tweepy import OAuthHandler

# %%
def get_twitter_auth():
    """Setup Twitter authentication.

    Return: tweepy.OAuthHandler object
    """
    try:
        consumer_key = 'ufSNyNj53P71GDibuS7Llu0DM'# os.environ['TWITTER_CONSUMER_KEY']
        consumer_secret = 'cjmnkM0pUCMI60NmyH4RtRm0DwygU9R1QA6HogJnzGIMJWfM8d' # os.environ['TWITTER_CONSUMER_SECRET']
        access_token = '164858584-XjZSmfxa8O5JTGtgxgzjjg0eglnitIj7hw67xN6p' # os.environ['TWITTER_ACCESS_TOKEN']
        access_secret = 'O9jHH2vtc1IuBGHFqaKnjsUWH0HZ8oLHYkPXBewPnMXcH' # os.environ['TWITTER_ACCESS_SECRET']
    except KeyError:
        sys.stderr.write("TWITTER_* environment variables not set\n")
        sys.exit(1)    
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    return auth

# %%
def get_twitter_client():
    """Setup Twitter API client.

    Return: tweepy.API object
    """
    auth = get_twitter_auth()
    client = API(auth)
    return client

# %% [markdown]
# ## Getting tweets from your timeline
# So the first thing I'm gonna do is to read my own tweets from my own timeline. For that, I'll use more stuff from Tweepy (the cursor) and also the library Json. The data dumped on us after we request something to Python API is in Json format. If you wanna learn more about that, feel free to enjoy http://www.w3schools.com/js/js_json_intro.asp

# %%
import json
from tweepy import Cursor

# %% [markdown]
# As you can see below there is no need for changes in the code. the client.home_timeline is the query for the Cursor, that will return 200 x 4 = 800 tweets from your home (that is the maximum you can get from your own timeline).
#
# **Notice** that a file named home_timeline.jsonl will be generated on the same folder as you saved this notebook! You can open this file to see a very messy information about all your tweets (one per line).

# %%
client = get_twitter_client()

with open('home_timeline.jsonl', 'w') as f:
    for page in Cursor(client.home_timeline, count=200, include_rts=True).pages(4):
        for status in page:
            # Process a single status
            f.write(json.dumps(status._json, indent=4)+"\n")

# %% [markdown]
# ## Activity 1
#
# Open the file called home_timeline.jsonl and read it. Use a text editor for that, like Gedit (Linux), Notepad (Windows) or TextEdit (Mac OSx).
# 1. What kind of information do you see in the file?
# 2. Can you get your tweets from the file? If yes, how?
# 3. Can you say what is the code doing by just reading the lines?

# %% [markdown]
# ## Getting tweets from another user's timeline
# You can also get information about another user's timeline. And the good news are: you can get more than the 800 tweets you got before! But now you have to give the username of the twitter account you wanna take the tweets. We will read 3200 tweets from VUamsterdam account.

# %%
# Give the name of the account you want to crawl the data from.
user = 'BillGates'
fname = "user_timeline_{}.jsonl".format(user)
# Out:
# BillGates
# user_timeline_BillGates.jsonl

# %%
# Collecting 16 pages of 200 tweets each.
with open(fname, 'w') as f:
    for page in Cursor(client.user_timeline, screen_name=user, count=200).pages(16):
        for status in page:
            f.write(json.dumps(status._json)+"\n")

# %% [markdown]
# ## Good to know!
# Using the Cursor to find tweets from your own account gives you a limit of 800 tweets maximum. When you use the second function, finding the tweets in a user timeline, this limit increaes to 3200.
#
# It is also good to know the structure of a tweet. In our code above the *_json* attribute is the one saved in the file. This attribute contains all the information from the tweet in a JSON format. The JSON format is useful to keep the structure of the information to be saved, and it is the same as a dictionary. In our case, we are creating a jsonl file, or a list of jsons, because every line corresponds to the information of a tweet.

# %% [markdown]
# ## Entity Analysis
#
# Now that we can get the tweets in a timeline, we can also extract the hashtags and produce the list with the more common ones.
#
# Remember that you have to change the name of your input (fname) if you are investigating another account!

# %%
from collections import Counter

def get_hashtags(tweet):
    entities = tweet.get('entities', {})
    hashtags = entities.get('hashtags', [])
    return [tag['text'].lower() for tag in hashtags]

# %%
# Read the file saved and extract the hashtags
with open(fname, 'r') as f:
    hashtags = Counter()
    for line in f:
        tweet = json.loads(line)
        hashtags_in_tweet = get_hashtags(tweet)
        hashtags.update(hashtags_in_tweet)
    for tag, count in hashtags.most_common(20):
        print("{}: {}".format(tag, count))
# Out:
# polio: 41
# endpolio: 40
# askbillg: 27
# ted: 17
# tbt: 15
# mdgs: 13
# teachers: 13
# givingtuesday: 12
# endmalaria: 12
# foreignaid: 11
# billsletter: 11
# malaria: 10
# hiv: 9
# ama: 9
# africa: 9
# india: 9
# g20: 8
# edtech: 7
# vaccineswork: 7
# smartaid: 7

# %% [markdown]
# ## Question about your data set:
# 1. Do you have any insight by looking at the hashtags found in the page you are verifying? Can you explain why those hashtags are the most used?

# %% [markdown]
# ### Going deeper...
#
# We can have deeper analysis of the statistics of the hashtags, instead of a simple counting of the number of times each one is used.

# %%
from collections import defaultdict

with open(fname, 'r') as f:
    hashtag_count = defaultdict(int)
    for line in f:
        tweet = json.loads(line)
        hashtags_in_tweet = get_hashtags(tweet)
        n_of_hashtags = len(hashtags_in_tweet)
        hashtag_count[n_of_hashtags] += 1

    tweets_with_hashtags = sum([count for n_of_tags, count in hashtag_count.items() if n_of_tags > 0])
    tweets_no_hashtags = hashtag_count[0]
    tweets_total = tweets_no_hashtags + tweets_with_hashtags
    # print tweets_total
    tweets_with_hashtags_percent = '{:2f}'.format(tweets_with_hashtags * 100.0 / tweets_total )
    tweets_no_hashtags_percent = "{:2f}".format(tweets_no_hashtags * 100.0 / tweets_total )
    # print tweets_no_hashtags_percent
    print("{0} tweets without hashtags ({1}%)".format(tweets_no_hashtags, tweets_no_hashtags_percent))
    print("{} tweets with at least one hashtag ({}%)".format(tweets_with_hashtags, tweets_with_hashtags_percent))

    for tag_count, tweet_count in hashtag_count.items():
        if tag_count > 0:
            percent_total = "%.2f" % float(tweet_count * 100.0 / tweets_total )
            percent_elite = "%.2f" % float(tweet_count * 100.0 / tweets_with_hashtags)
            print("{} tweets with {} hashtags ({}% total, {}% elite)".format(tweet_count,
                                                                             tag_count,
                                                                             percent_total,
                                                                             percent_elite))
# Out:
# 1935 tweets without hashtags (76.694411%)
# 588 tweets with at least one hashtag (23.305589%)
# 482 tweets with 1 hashtags (19.10% total, 81.97% elite)
# 91 tweets with 2 hashtags (3.61% total, 15.48% elite)
# 13 tweets with 3 hashtags (0.52% total, 2.21% elite)
# 1 tweets with 4 hashtags (0.04% total, 0.17% elite)
# 1 tweets with 8 hashtags (0.04% total, 0.17% elite)

# %% [markdown]
# ## User mentions on tweets
#
# In a similar way we can see user mentions

# %%
def get_mentions(tweet):
    entities = tweet.get('entities', {})
    hashtags = entities.get('user_mentions', [])
    return [tag['screen_name'] for tag in hashtags]

# %%
with open(fname, 'r') as f:
    users = Counter()
    for line in f:
        tweet = json.loads(line)
        mentions_in_tweet = get_mentions(tweet)
        users.update(mentions_in_tweet)
    for user, count in users.most_common(20):
        print("{}: {}".format(user, count))
# Out:
# melindagates: 109
# gatesfoundation: 65
# BillGates: 33
# WarrenBuffett: 29
# TheEconomist: 26
# ONECampaign: 26
# HansRosling: 25
# reddit: 18
# DonorsChoose: 16
# nytimes: 15
# SueDHellmann: 15
# NickKristof: 12
# johngreen: 12
# WIRED: 12
# UNICEF: 11
# realjohngreen: 11
# charlesjkenny: 11
# sapinker: 11
# Atul_Gawande: 10
# BillClinton: 9

# %% [markdown]
# ## Tokenization and Text Analysis
# Now we are gonna read the text of the tweets and process some of the words, checking some statistics also. For this we will use the NLTK library.

# %% [markdown]
# #### In case you have a problem like the one below, uncomment the following lines:
# ![./Problem01.png](./Problem01.png)
#
# ![./Problem01.png](./Solution01.png)

# %% [markdown]
# NLTK will be our Natural Language Library! You have to install it (possibly) to make the code work. So uncomment the code below if necessary, and after you install it, then comment it again.

# %%
import nltk
#nltk.download()

# %%
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import string

# %%
def process(text, tokenizer=TweetTokenizer(), stopwords=[]):
    """Process the text of a tweet:
    - Lowercase
    - Tokenize
    - Stopword removal
    - Digits removal

    Return: list of strings
    """
    text = text.lower()
    tokens = tokenizer.tokenize(text)
    
    # If we want to normalize contraction, uncomment this
    tokens = normalize_contractions(tokens)
    return [tok for tok in tokens if tok not in stopwords and not tok.isdigit() and tok != u'\u2026']

# %%
def normalize_contractions(tokens):
    """Example of normalization for English contractions.

    Return: generator
    """
    token_map = {
        "i'm": "i am",
        "you're": "you are",
        "it's": "it is",
        "we're": "we are",
        "we'll": "we will",
    }
    for tok in tokens:
        if tok in token_map.keys():
            for item in token_map[tok].split():
                yield item
        else:
            yield tok

# %%
tweet_tokenizer = TweetTokenizer()

punct = list(string.punctuation)
stopword_list = stopwords.words('english') + punct + ['rt', 'via'] 

tf = Counter()
with open(fname, 'r') as f:
    for line in f:
        tweet = json.loads(line)
        tokens = process(text=tweet.get('text', ''),
                         tokenizer=tweet_tokenizer,
                         stopwords=stopword_list)
        tf.update(tokens)
    for tag, count in tf.most_common(1000):
        print("\'{}\': {}".format(tag.encode('utf-8'), count))
# Out:
# '’': 816
# 'great': 252
# 'world': 217
# 'people': 162
# 'one': 161
# '...': 147
# 'new': 146
# 'help': 136
# 'lives': 118
# '@melindagates': 109
# 'progress': 106
# '”': 106
# '“': 104
# 'video': 103
# 'work': 103
# 'energy': 100
# 'book': 97
# 'global': 95
# 'polio': 95
# 'see': 93
# 'w': 92
# 'health': 91
# 'today': 87
# 'students': 85
# 'read': 84
# 'could': 81
# 'africa': 80
# 'melinda': 80
# 'fight': 79
# 'make': 79
# 'poverty': 73
# 'year': 71
# 'better': 71
# 'need': 70
# 'get': 69
# 'good': 68
# 'talk': 67
# 'learn': 66
# '@gatesfoundation': 66
# 'teachers': 66
# 'life': 65
# 'aid': 65
# 'future': 65
# 'thanks': 62
# 'live': 62
# 'like': 62
# 'us': 61
# 'india': 60
# 'time': 57
# 'next': 57
# 'save': 57
# 'trip': 57
# 'best': 56
# 'support': 56
# 'think': 55
# 'years': 54
# 'malaria': 54
# 'women': 54
# 'poor': 53
# 'join': 53
# 'countries': 53
# 'much': 52
# 'many': 52
# '—': 52
# 'letter': 51
# 'children': 50
# 'change': 49
# '–': 49
# 'every': 49
# 'innovation': 49
# 'favorite': 48
# 'way': 48
# 'day': 48
# 'ever': 47
# 'watch': 47
# 'important': 45
# 'big': 45
# 'would': 45
# 'working': 44
# 'impact': 43
# 'first': 43
# 'look': 42
# 'amazing': 42
# 'annual': 42
# '#polio': 41
# '#endpolio': 41
# 'vaccines': 40
# 'lot': 40
# 'incredible': 40
# 'books': 39
# 'making': 39
# 'explains': 39
# 'made': 39
# 'questions': 38
# 'back': 37
# 'disease': 37
# 'end': 37
# 'excited': 36
# 'child': 35
# 'u': 35
# 'poorest': 35
# 'news': 35
# 'story': 35
# 'last': 34
# 'know': 34
# 'want': 33
# 'hiv': 33
# 'education': 33
# 'interesting': 33
# '@billgates': 33
# 'ebola': 33
# 'improve': 33
# 'data': 32
# 'million': 32
# 'take': 32
# 'thank': 32
# 'find': 32
# 'got': 32
# 'ted': 32
# 'research': 31
# 'may': 31
# 'week': 31
# 'vaccine': 31
# 'getting': 31
# 'looking': 30
# 'really': 30
# 'commitment': 30
# 'aids': 30
# 'helping': 30
# 'happy': 29
# 'learning': 29
# 'everyone': 29
# '@warrenbuffett': 29
# 'foundation': 28
# 'love': 28
# 'around': 28
# 'science': 28
# 'might': 28
# 'hard': 28
# 'development': 28
# 'talking': 28
# 'millions': 28
# 'college': 28
# '#askbillg': 27
# 'tools': 27
# 'together': 27
# 'since': 27
# 'answer': 27
# 'foreign': 27
# 'diseases': 27
# 'ideas': 27
# 'kids': 26
# '@onecampaign': 26
# 'teacher': 26
# 'hope': 26
# 'still': 26
# 'start': 26
# 'go': 26
# '@theeconomist': 26
# 'billion': 26
# 'visit': 26
# 'approach': 26
# 'recently': 26
# 'makes': 25
# 'warren': 25
# '@hansrosling': 25
# 'friend': 25
# 'learned': 25
# 'history': 25
# 'give': 25
# 'optimistic': 25
# 'fascinating': 25
# 'reading': 25
# 'meeting': 25
# 'fighting': 25
# 'inspired': 24
# 'food': 24
# 'stories': 24
# 'even': 24
# 'thoughts': 24
# 'school': 24
# 'epidemic': 24
# 'team': 23
# 'always': 23
# 'met': 23
# 'here's': 23
# 'gates': 23
# 'two': 23
# 'fun': 23
# 'cool': 23
# 'review': 23
# 'without': 23
# 'photos': 22
# 'scientists': 22
# 'recent': 22
# 'meet': 22
# 'never': 22
# 'others': 22
# 'extreme': 22
# 'check': 22
# 'ethiopia': 22
# 'leadership': 21
# 'young': 21
# 'another': 21
# 'post': 21
# 'giving': 21
# 'remarkable': 21
# 'possible': 20
# 'saving': 20
# 'technology': 20
# 'chat': 20
# 'climate': 20
# 'business': 20
# 'investing': 20
# 'q': 20
# 'innovations': 20
# 'free': 20
# 'report': 20
# 'farmers': 20
# 'list': 20
# 'notes': 20
# 'article': 19
# 'powerful': 19
# 'share': 19
# 'needs': 19
# 'forward': 19
# 'inspiring': 19
# 'helped': 19
# 'success': 19
# 'leaders': 19
# 'project': 18
# 'lots': 18
# '@reddit': 18
# 'summer': 18
# 'uk': 18
# 'ask': 18
# 'piece': 18
# 'girls': 18
# 'ending': 18
# 'critical': 18
# 'difference': 18
# 'idea': 18
# 'investment': 18
# 'invest': 18
# 'conversation': 18
# 'tb': 17
# 'philanthropy': 17
# 'hunger': 17
# 'let': 17
# 'spread': 17
# 'discuss': 17
# 'shows': 17
# 'tomorrow': 17
# 'developing': 17
# 'clean': 17
# '#ted': 17
# 'well': 17
# 'coming': 17
# 'latest': 17
# 'deaths': 17
# 'water': 17
# 'things': 16
# 'proud': 16
# 'going': 16
# 'power': 16
# 'fund': 16
# 'tonight': 16
# 'yrs': 16
# '@donorschoose': 16
# 'thinking': 16
# 'nigeria': 16
# 'key': 16
# 'eradication': 16
# 'dad': 16
# 'says': 16
# 'r': 16
# 'reasons': 16
# 'problems': 16
# 'use': 16
# 'country': 15
# 'chance': 15
# 'saved': 15
# 'photo': 15
# '@suedhellmann': 15
# 'challenges': 15
# 'death': 15
# 'family': 15
# '@nytimes': 15
# 'partners': 15
# 'human': 15
# 'sharing': 15
# 'thing': 15
# 'little': 15
# 'show': 15
# 'money': 15
# 'believe': 15
# 'loved': 15
# 'taking': 15
# 'huge': 15
# 'tweet': 15
# 'come': 15
# 'case': 15
# 'program': 15
# 'job': 15
# '#tbt': 15
# 'tech': 14
# 'lessons': 14
# 'posted': 14
# 'agree': 14
# 'reduce': 14
# 'challenge': 14
# 'innovative': 14
# 'away': 14
# 'tough': 14
# 'phenomenal': 14
# 'care': 14
# 'using': 14
# 'mobile': 14
# 'anyone': 14
# 'videos': 14
# 'starting': 14
# 'benefits': 14
# 'part': 14
# 'chart': 14
# 'often': 14
# 'helps': 14
# 'must': 14
# 'population': 14
# 'ways': 14
# 'short': 14
# 'reach': 14
# 'issues': 14
# 'toilets': 14
# 'mosquitoes': 14
# '#mdgs': 13
# 'set': 13
# 'world's': 13
# 'welcome': 13
# 'online': 13
# 'ceo': 13
# 'treatment': 13
# 'american': 13
# 'smart': 13
# 'stop': 13
# 'website': 13
# 'economic': 13
# '#teachers': 13
# 'living': 13
# 'long': 13
# 'potential': 13
# 'behind': 13
# 'promising': 13
# 'funding': 13
# 'done': 13
# 'bill': 13
# 'access': 13
# 'biggest': 13
# 'earth': 13
# 'efforts': 13
# 'blog': 13
# 'something': 13
# 'growth': 13
# 'eradicate': 12
# 'saw': 12
# '#givingtuesday': 12
# '@nickkristof': 12
# 'imagine': 12
# 'budget': 12
# 'ago': 12
# 'worth': 12
# 'discussion': 12
# 'america': 12
# '@wired': 12
# 'issue': 12
# 'keep': 12
# 'http': 12
# 'investments': 12
# 'yes': 12
# 'enough': 12
# 'advice': 12
# 'simple': 12
# 'spend': 12
# 'times': 12
# 'place': 12
# '@johngreen': 12
# '#endmalaria': 12
# 'workers': 12
# 'light': 12
# 'i've': 12
# 'electricity': 11
# 'example': 11
# 'eradicating': 11
# 'asked': 11
# 'easy': 11
# 'improving': 11
# 'course': 11
# 'breakthrough': 11
# 'small': 11
# 'past': 11
# 'beautiful': 11
# 'came': 11
# 'pledge': 11
# 'high': 11
# 'webcast': 11
# 'site': 11
# 'interview': 11
# '@realjohngreen': 11
# 'real': 11
# '@sapinker': 11
# 'actually': 11
# '#foreignaid': 11
# 'reason': 11
# 'close': 11
# 'seeing': 11
# 'facebook': 11
# 'humans': 11
# 'fantastic': 11
# 'mortality': 11
# 'president': 11
# 'opportunity': 11
# 'growing': 11
# 'map': 11
# 'honor': 11
# 'minutes': 11
# '@unicef': 11
# 'changed': 11
# 'excellent': 11
# 'impressive': 11
# 'cases': 11
# '@charlesjkenny': 11
# '#billsletter': 11
# 'view': 11
# 'half': 11
# 'exciting': 11
# 'schools': 10
# 'tune': 10
# 'role': 10
# 'prevent': 10
# 'sign': 10
# 'address': 10
# 'ghana': 10
# 'also': 10
# 'community': 10
# 'projects': 10
# 'un': 10
# '#malaria': 10
# 'government': 10
# 'enjoyed': 10
# 'kenya': 10
# 'pst': 10
# 'put': 10
# 'soon': 10
# 'committed': 10
# 'ready': 10
# 'started': 10
# 'talks': 10
# 'home': 10
# 'goals': 10
# 'recommend': 10
# 'bono': 10
# 'went': 10
# 'digital': 10
# 'african': 10
# 'nearly': 10
# 'create': 10
# 'spent': 10
# 'partner': 10
# 'enjoy': 10
# 'london': 10
# 'solutions': 10
# 'crisis': 10
# 'classroom': 10
# 'cheap': 10
# 'state': 10
# 'toilet': 10
# 'far': 10
# 'teach': 10
# 'feed': 10
# '@atul_gawande': 10
# 'leader': 10
# 'breakthroughs': 10
# 'four': 9
# 'hero': 9
# 'china': 9
# 'easier': 9
# 'malnutrition': 9
# 'right': 9
# 'congratulations': 9
# 'say': 9
# 'number': 9
# 'try': 9
# 'fact': 9
# 'less': 9
# 'problem': 9
# 'phones': 9
# '@khanacademy': 9
# 'rates': 9
# 'true': 9
# 'test': 9
# 'shared': 9
# 'comes': 9
# 'poop': 9
# 'thoughtful': 9
# 'takes': 9
# '#india': 9
# 'used': 9
# 'immunization': 9
# 'step': 9
# '#hiv': 9
# 'including': 9
# 'university': 9
# 'special': 9
# '@rotary': 9
# 'meat': 9
# 'seen': 9
# 'explain': 9
# 'bad': 9
# 'three': 9
# 'left': 9
# 'gatesnotes': 9
# 'across': 9
# 'solve': 9
# '#ama': 9
# 'fwd': 9
# 'common': 9
# '@wsj': 9
# 'south': 9
# 'visited': 9
# 'thought': 9
# 'match': 9
# '@billclinton': 9
# 'conference': 9
# 'mt': 9
# 'days': 9
# '@graphite': 9
# 'hear': 9
# 'focus': 9
# 'sure': 9
# 'hungry': 9
# 'milestone': 9
# 'kind': 9
# 'income': 9
# 'happen': 9
# 'available': 8
# 'spoke': 8
# 'effective': 8
# 'wish': 8
# 'reducing': 8
# 'brilliant': 8
# 'bright': 8
# 'scientific': 8
# 'full': 8
# '@msftresearch': 8
# 'surprised': 8
# 'continue': 8
# 'anything': 8
# 'code': 8
# 'results': 8
# 'send': 8
# 'animal': 8
# 'bring': 8
# 'lucky': 8
# '@ryanseacrest': 8
# 'five': 8
# 'become': 8
# 'davos': 8
# 'places': 8
# 'bank': 8
# 'dr': 8
# 'innovators': 8
# 'update': 8
# 'optimism': 8
# 'terrific': 8
# 'else': 8
# 'carter': 8
# 'measure': 8
# 'cause': 8
# 'computer': 8
# 'teaching': 8
# 'companies': 8
# 'tell': 8
# 'matter': 8
# 'talked': 8
# 'man': 8
# 'sounds': 8
# 'least': 8
# 'newborn': 8
# 'cut': 8
# 'matters': 8
# '#africa': 8
# 'almost': 8
# '@qz': 8
# 'risk': 8
# 'tool': 8
# 'inspire': 8
# 'haiti': 8
# 'protect': 8
# 'everything': 8
# '#g20': 8
# 'insights': 8
# 'birthday': 8
# 'happened': 8
# 'importance': 8
# 'reminder': 8
# 'researchers': 8
# 'deserve': 8
# 'missed': 8
# 'follow': 8
# 'rate': 8
# 'wrote': 8
# 'c': 8
# 'impressed': 8
# 'question': 8
# 'waiting': 8
# 'maternal': 8
# 'closer': 8
# 'successful': 7
# 'listen': 7
# 'fail': 7
# '@who': 7
# ':/': 7
# 'everywhere': 7
# '#edtech': 7
# 'sat': 7
# '@mikebloomberg': 7
# 'guest': 7
# 'antarctica': 7
# 'sometimes': 7
# 'involved': 7
# 'agriculture': 7
# 'system': 7
# 'means': 7
# 'stuff': 7
# '#smartaid': 7
# 'paul': 7
# 'rosling': 7
# 'software': 7
# '@nytimesfriedman': 7
# 'provide': 7
# 'lab': 7
# 'highlights': 7
# 'buffett': 7
# 'polio-free': 7
# '@jeffraikes': 7
# 'born': 7
# 'different': 7
# 'turns': 7
# 'cost': 7
# 'heard': 7
# 'heroes': 7
# 'celebrate': 7
# 'favorites': 7
# 'trying': 7
# 'storage': 7
# '@tedchris': 7
# 'inspires': 7
# 'khan': 7
# 'pretty': 7
# 'recommendations': 7
# 'revolution': 7
# 'headed': 7
# 'uses': 7
# 'within': 7
# 'info': 7
# 'michael': 7
# 'bed': 7
# 'twitter': 7
# 'washington': 7
# 'friends': 7
# 'call': 7
# 'point': 7
# '#vaccineswork': 7
# 'yet': 7
# 'mdgs': 7
# 'effort': 7
# 'americans': 7
# 'morning': 7
# 'speech': 7
# 'field': 7
# '@microsoft': 7
# 'raise': 7
# 'gap': 7
# 'understand': 7
# 'yesterday': 7
# 'bit': 7
# 'planet': 7
# 'calling': 7
# 'tremendous': 7
# 'unicef': 7
# '@bighistorypro': 7
# 'writing': 7
# 'sanitation': 7
# 'greatest': 7
# 'gave': 7
# 'local': 7
# 'dropped': 7
# 'conversations': 7
# 'childhood': 7
# 'gives': 7
# 'author': 7
# 'goal': 7
# 'don't': 7
# 'hit': 7
# 'attention': 7
# 'essential': 7
# 'farming': 7
# 'looks': 7
# 'student': 7
# 'lead': 7
# 'feedback': 6
# 'series': 6
# 'today's': 6
# 'nations': 6
# 'accelerate': 6
# 'carbon': 6
# 'dengue': 6
# 'old': 6
# 'resources': 6
# 'decades': 6
# 'quite': 6
# 'massive': 6
# 'sad': 6
# 'deadliest': 6
# '@globalfund': 6
# '@guardian': 6
# '#tedxchange': 6
# 'empower': 6
# 'hours': 6
# 'social': 6
# 'plans': 6
# 'courses': 6
# 'play': 6
# 'plan': 6
# 'guinea': 6
# '):': 6
# 'funny': 6
# 'person': 6
# 'yergin': 6
# 'spending': 6
# 'essay': 6
# 'fewer': 6
# 'david': 6
# 'partnership': 6
# 'face': 6
# 'decade': 6
# 'waste': 6
# 'spain': 6
# 'safe': 6
# 'daniel': 6
# 'medicine': 6
# '@ihme_uw': 6
# '#superpowerforgood': 6
# 'families': 6
# 'honored': 6
# 'computing': 6
# 'interested': 6
# 'glad': 6
# 'economy': 6
# 'increase': 6
# 'tropical': 6
# 'finish': 6
# 'early': 6
# '@ozy': 6
# '@vaclavsmil': 6
# '#aids': 6
# 'month': 6
# 'i'll': 6
# 'answers': 6
# 'strong': 6
# 'event': 6
# 'toward': 6
# 'zambia': 6
# 'pictures': 6
# 'grand': 6
# 'eradicated': 6
# 'download': 6
# 'beijing': 6
# 'africans': 6
# 'written': 6
# 'quiz': 6
# 'stay': 6
# '@npr': 6
# 'saves': 6
# 'net': 6
# 'crucial': 6
# 'surprise': 6
# 'turning': 6
# 'starts': 6
# 'tennis': 6
# 'died': 6
# 'die': 6
# 'wait': 6
# 'crazy': 6
# 'affordable': 6
# 'tour': 6
# 'remote': 6
# 'hour': 6
# 'numbers': 6
# 'maps': 6
# 'source': 6
# 'jimmy': 6
# 'fan': 6
# 'congrats': 6
# 'mit': 6
# 'compelling': 6
# 'already': 6
# 'took': 6
# '@voxdotcom': 6
# 'devastating': 6
# 'pick': 6
# 'mosquito': 6
# 'transform': 6
# 'goes': 6
# 'vital': 6
# 'farmer': 6
# 'superman': 6
# 'changing': 6
# 'sub-saharan': 6
# 'we've': 6
# 'donations': 6
# 'provides': 6
# 'opportunities': 6
# '#worldaidsday': 6
# 'return': 6
# 'alzheimer': 6
# 'succeed': 6
# 'chickens': 6
# 'steve': 6
# '@narendramodi': 6
# 'stream': 6
# 'banking': 6
# 'class': 6
# '#vr': 6
# 'thousands': 6
# 'watching': 6
# 'qs': 6
# 'gets': 6
# 'whether': 6
# 'brought': 5
# '@dfid_uk': 5
# 'wrong': 5
# '#futureoffood': 5
# 'encourage': 5
# 'rice': 5
# 'parents': 5
# 'lift': 5
# 'life-saving': 5
# 'donation': 5
# 'launching': 5
# 'ambitious': 5
# 'leave': 5
# 'positive': 5
# 'explores': 5
# 'truly': 5
# 'infected': 5
# 'argument': 5
# 'infections': 5
# 'jobs': 5
# 'gdp': 5
# 'couldn't': 5
# 'myths': 5
# 'nelson': 5
# 'consider': 5
# 'joined': 5
# 'pics': 5
# 'company': 5
# 'found': 5
# 'bihar': 5
# 'firsthand': 5
# '@theatlantic': 5
# 'reliable': 5
# 'curious': 5
# 'deserves': 5
# 'link': 5
# 'accounts': 5
# 'blown': 5
# 'economist': 5
# 'h': 5
# 'harvard': 5
# 'cc': 5
# '@un': 5
# 'stage': 5
# 'documentary': 5
# '@forbes': 5
# 'deadly': 5
# 'inspiration': 5
# 'math': 5
# 'award': 5
# 'word': 5
# 'green': 5
# 'nets': 5
# 'deeply': 5
# 'dc': 5
# 'speak': 5
# 'hans': 5
# 'visualization': 5
# 'generosity': 5
# 'dying': 5
# 'battle': 5
# '#bighistory': 5
# 'ed': 5
# 'message': 5
# 'forever': 5
# 'miracle': 5
# 'you've': 5
# 'launch': 5
# 'partnerships': 5
# 'preventable': 5
# 'guide': 5
# 'game': 5
# 'berkshire': 5
# 'gender': 5
# 'cell': 5
# '#globalgoals': 5
# 'able': 5
# 'fuel': 5
# 'stats': 5
# 'demo': 5
# 'page': 5
# 'eat': 5
# 'affect': 5
# 'solution': 5
# 'donors': 5
# 'sal': 5
# 'interest': 5
# 'well-deserved': 5
# 'seattle': 5
# 'weekend': 5
# 'daily': 5
# 'answered': 5
# 'afghanistan': 5
# '@alwaleed_talal': 5
# 'group': 5
# 'answering': 5
# 'track': 5
# 'surprising': 5
# '@red': 5
# '#toilet': 5
# 'passionate': 5
# 'lifetime': 5
# 'tackle': 5
# 'mandela': 5
# '#dataviz': 5
# 'response': 5
# 'members': 5
# 'kipp': 5
# 'b': 5
# 'interactive': 5
# 'build': 5
# 'joining': 5
# 'visiting': 5
# '@arpae': 5
# 'century': 5
# 'moment': 5
# 'hopes': 5
# 'entire': 5
# 'later': 5
# 'despite': 5
# 'reached': 5
# 'beat': 5
# 'national': 5
# '@nothingbutnets': 5
# 'center': 5
# 'protecting': 5
# 'works': 5
# '#familyplanning': 5
# 'reminds': 5
# 'path': 5
# 'wanted': 5
# 'top': 5
# 'effectiveness': 5
# 'announce': 5
# 'tuberculosis': 5
# 'complex': 5
# 'mother': 5
# 'humanity': 5
# 'gift': 5
# 'core': 5
# 'faster': 5
# 'environment': 5
# 'turn': 5
# 'returns': 5
# 'nathan': 5
# 'reduced': 5
# 'invention': 5
# 'design': 5
# 'markets': 5
# 'inequality': 5
# 'generation': 5
# '@charlierose': 5
# 'feel': 5
# 'brave': 5
# 'village': 5
# 'pm': 5
# 'fast': 5
# 'dramatically': 5
# 'traveling': 5
# 'explore': 5
# 'clever': 5
# 'column': 5

# %% [markdown]
# ### Plotting frequency
#
# Instead of printing the values of frequency we can create graphics that allow us to visualize the results better.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np

tweet_tokenizer = TweetTokenizer()
punct = list(string.punctuation)
stopword_list = stopwords.words('english') + punct + ['rt', 'via']


tf = Counter()
with open(fname, 'r') as f:
    for line in f:
        tweet = json.loads(line)
        tokens = process(text=tweet.get('text', ''),
                         tokenizer=tweet_tokenizer,
                         stopwords=stopword_list)
        tf.update(tokens)
        
    tags = [tag for tag, count in tf.most_common(1000)]
    
    #print tags
    y = [count for tag, count in tf.most_common(1000)]
    x = range(1, len(y)+1)

    plt.figure(figsize=(14,7), dpi=300)

    plt.bar(x, y, align='center', alpha=0.5)
    plt.title("Term Frequencies")
    plt.ylabel("Frequency")
    plt.xticks(range(1,len(tags)+1), tags, rotation=90)
    plt.savefig('term_distribution.png')

# %%
### The same can be done for the hashtags

# %%
def get_hashtags(tweet):
    entities = tweet.get('entities', {})
    hashtags = entities.get('hashtags', [])
    return [tag['text'].lower() for tag in hashtags]

print(user)
fname = 'user_timeline_BillGates.jsonl'
with open(fname, 'r') as f:
    hashtags = Counter()
    for line in f:
        tweet = json.loads(line)
        hashtags_in_tweet = get_hashtags(tweet)
        hashtags.update(hashtags_in_tweet)
    for tag, count in hashtags.most_common(1000):
        print("{}: {}".format(repr(tag), count))

    tags = [tag for tag, count in hashtags.most_common(1000)]
    
    #print tags
    y = [count for tag, count in hashtags.most_common(1000)]
    x = range(1, len(y)+1)

    plt.figure(figsize=(14,7), dpi=300)

    plt.bar(x, y, align='center', alpha=0.5)
    plt.title("Hashtags Frequencies")
    plt.ylabel("Frequency")
    plt.xticks(range(1,len(tags)+1), tags, rotation=90)
    plt.savefig('hashtags_distribution.png')
# Out:
# BillGates
# u'polio': 41
# u'endpolio': 40
# u'askbillg': 27
# u'ted': 17
# u'tbt': 15
# u'mdgs': 13
# u'teachers': 13
# u'givingtuesday': 12
# u'endmalaria': 12
# u'foreignaid': 11
# u'billsletter': 11
# u'malaria': 10
# u'hiv': 9
# u'ama': 9
# u'africa': 9
# u'india': 9
# u'g20': 8
# u'edtech': 7
# u'vaccineswork': 7
# u'smartaid': 7
# u'tedxchange': 6
# u'aids': 6
# u'vr': 6
# u'superpowerforgood': 6
# u'worldaidsday': 6
# u'globalgoals': 5
# u'familyplanning': 5
# u'bighistory': 5
# u'toilet': 5
# u'dataviz': 5
# u'futureoffood': 5
# u'fiscalsummit': 4
# u'ethiopia': 4
# u'tb': 4
# u'globalhealth': 4
# u'energy': 4
# u'mdg': 4
# u'nerdfighters': 4
# u'pakistan': 4
# u'ted2015': 4
# u'cleanenergy': 4
# u'rednoseday': 4
# u'livingproof': 4
# u'tedtalksed': 4
# u'worldtoiletday': 3
# u'stopthemyth': 3
# u'wef': 3
# u'nocontroversy': 3
# u'iac2012': 3
# u'innovation': 3
# u'tuberculosis': 3
# u'backtoschool': 3
# u'givingpledge': 3
# u'wpd11': 3
# u'wwd': 3
# u'vaccines': 3
# u'renewableenergy': 3
# u'wha65': 3
# u'tedtalks': 3
# u'hourofcode': 3
# u'wad11': 3
# u'tedtalk': 3
# u'ukaid': 3
# u'bgct': 3
# u'fpsummit': 3
# u'seattle': 3
# u'csforall': 2
# u'infographic': 2
# u'climatechange': 2
# u'gulf': 2
# u'thankateacher': 2
# u'ag': 2
# u'saturdaylive': 2
# u'ghana': 2
# u'zambia': 2
# u'extremepoverty': 2
# u'hbcu': 2
# u'globaldev': 2
# u'nerdnation': 2
# u'agdev': 2
# u'ebola': 2
# u'toilets': 2
# u'ifcampaign': 2
# u'stem': 2
# u'china': 2
# u'aid': 2
# u'wsjeco': 2
# u'bigif': 2
# u'worldtbday': 2
# u'facsumm': 2
# u'davos': 2
# u'worldmalariaday': 2
# u'imallin': 2
# u'leanintogether': 2
# u'worldpolioday': 2
# u'fallontonight': 2
# u'iste13': 2
# u'worldcup': 2
# u'stanford14': 2
# u'education': 2
# u'mygivingstory': 2
# u'hopefor2030': 2
# u'desertislanddiscs': 2
# u'betterworld': 2
# u'g8': 2
# u'tanzania': 2
# u'talktome': 1
# u'pkfloods': 1
# u'startswithme': 1
# u'teacherprize': 1
# u'stopkony': 1
# u'givebig': 1
# u'als': 1
# u'ebolaresponse': 1
# u'cgi2013': 1
# u'blackfriday': 1
# u'ksa': 1
# u'ghc17': 1
# u'thankspaul': 1
# u'aids2016': 1
# u'aids2012': 1
# u'onesecondmarch': 1
# u'4mlives': 1
# u'nmal2016': 1
# u'wrad': 1
# u'halfthesky': 1
# u'idol': 1
# u'naturalgas': 1
# u'literacy': 1
# u'morethanagoal': 1
# u'mlkday': 1
# u'ebolachat': 1
# u'2030now': 1
# u'ted2011': 1
# u'rednose25': 1
# u'namibia': 1
# u'science': 1
# u'mosquitoday': 1
# u'tropmed14': 1
# u'2013gc': 1
# u'conqueringthechaos': 1
# u'qanda': 1
# u'starwars': 1
# u'goalkeepers17': 1
# u'abudhabi': 1
# u'hoacrisis': 1
# u'bigdebate': 1
# u'xboxone': 1
# u'moocs': 1
# u'books': 1
# u'whsciencefair': 1
# u'gatesletterdotcom': 1
# u'endfamine': 1
# u'nuclearenergy': 1
# u'cybermonday': 1
# u'momentsmatter': 1
# u'sandy': 1
# u'gettysburgaddress': 1
# u'weekendread': 1
# u'post2015': 1
# u'giving': 1
# u'bighistoryproject': 1
# u'sotu': 1
# u'health': 1
# u'dimbleby': 1
# u'existentialism': 1
# u'bono': 1
# u'foodforthought': 1
# u'mpesa': 1
# u'pilgf': 1
# u'malnutrition': 1
# u'redworldrecord': 1
# u'menafrivac': 1
# u'rotavirus': 1
# u'tedtalksedu': 1
# u'water': 1
# u'bestof2014': 1
# u'nerdfighter': 1
# u'solidays': 1
# u'passiton': 1
# u'greatreads': 1
# u'teacher': 1
# u'imaginecup': 1
# u'helppakistan': 1
# u'norway': 1
# u'hitrefresh': 1
# u'biosphere': 1
# u'gearvr': 1
# u'cleantech': 1
# u'energyinnovation': 1
# u'sb48': 1
# u'library': 1
# u'tackleebola': 1
# u'educationnation': 1
# u'ted2014': 1
# u'nationalteacherday': 1
# u'ted2013': 1
# u'maternalhealth': 1
# u'wad2012': 1
# u'womenandgirls': 1
# u'code': 1
# u'agriculture': 1
# u'foodrevolution': 1
# u'chad': 1
# u'philanthropy': 1
# u'crowdsourcing': 1
# u'southafrica': 1
# u'renewable': 1
# u'mohamed_bin_zayed': 1
# u'nigeria': 1
# u'longreads': 1
# u'malawi': 1
# u'worldhealthday': 1
# u'givingawards': 1
# u'meningitis': 1
# u'g82013': 1
# u'principles': 1
# u'madmen': 1
# u'sugamitra': 1
# u'endntds': 1
# u'globalcitizen': 1
# u'rosieproject': 1
# u'girlsandwomen': 1
# u'sanitation': 1
# u'aidworks': 1
# u'sportrelief': 1
# u'edtechchat': 1
# u'un': 1
# u'youth': 1
# u'foodprices': 1
# u'unwomen': 1
# u'grandchallenges': 1
# u'5thbday': 1
# u'poopwater': 1
# u'myhope2030': 1
# u'immunization': 1
# u'mifindex': 1
# u'kenya': 1
# u'uae': 1
# u'botswana': 1
# u'if': 1
# u'daca': 1
# u'tldr': 1
# u'globalmnh': 1
# u'ag4dev': 1
# u'haiti': 1
# u'bestschoolday': 1
# u'wheniwas15': 1
# u'unga': 1
# u'wimbledon': 1
# u'development': 1
# u'iwd': 1
# u'maternal': 1
# u'7billion': 1
# u'newu2song': 1
# u'onlinelearning': 1
# u'nationalbookloversday': 1
# u'connected': 1
# u'kenyans': 1
# u'stateofwomen': 1
# u'nonprofits': 1
# u'marathonman': 1
# u'wpdchat': 1
# u'lifesaver': 1
# u'sharkweek': 1
# u'mobile': 1
# u'farmers': 1
# u'battleofthesexes': 1
# u'fcbarcelona': 1
# u'bambi': 1
# u'billatted': 1
# u'rednose4kids': 1
# u'idolgivesback': 1
# u'toiletfair': 1
# u'mobilemoney': 1
# u'icfp': 1

# %% [markdown]
# ## Activity 2
# You might have run the code up to now based on the original example of the VU Amsterdam profile. Pick a new profile on Twitter and run the first part again. Also change the code above to show the 1000 most common hashtags.
#
# Can you tell about the results you obtained?
# 1. Why did you pick this page?
# 2. What is interesting about it when you verify the hashtags and the most common words?
# 3. What else would be interesting to do with the data obtained in this data set?

# %% [markdown]
# # Streaming
# Streaming is a way to keep a 'door' open listening to the twitter flow of interactions over time. This allow us to collect more data than permited with all the restrictions of the API.

# %%
import string
import time
from tweepy import Stream
from tweepy.streaming import StreamListener

# %%
def format_filename(fname):
    """Convert fname into a safe string for a file name.

    Return: string
    """
    return ''.join(convert_valid(one_char) for one_char in fname)

# %%
def convert_valid(one_char):
    """Convert a character into '_' if "invalid".

    Return: string
    """
    valid_chars = "-_.%s%s" % (string.ascii_letters, string.digits)
    if one_char in valid_chars:
        return one_char
    else:
        return '_'

# %%
class CustomListener(StreamListener):
    """Custom StreamListener for streaming Twitter data."""

    def __init__(self, fname):
        safe_fname = format_filename(fname)
        self.outfile = "stream_%s.jsonl" % safe_fname

    def on_data(self, data):
        try:
            with open(self.outfile, 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            sys.stderr.write("Error on_data: {}\n".format(e))
            time.sleep(5)
        return True

    def on_error(self, status):
        if status == 420:
            sys.stderr.write("Rate limit exceeded\n".format(status))
            return False
        else:
            sys.stderr.write("Error {}\n".format(status))
            return True

# %% [markdown]
# The **stream** will run for 120 seconds and the query is Ajax OR footbal. If you want the occurrence of two values together, like Ajax AND football, we should pass the query = ['Ajax footbal']

# %%
query = ['polio', 'malaria']
query_fname = ' '.join(query) # string
auth = get_twitter_auth()
twitter_stream = Stream(auth, CustomListener(query_fname))
twitter_stream.filter(track=query, async=True)
time.sleep(120)
# TO stop your streaming...
twitter_stream.running = False

# %%
# To stop your streaming before the time set...
twitter_stream.running = False

# %% [markdown]
# ## Activity 3
#
# Now, create your own query, and pay attention on where are the results of the query being saved. Can you tell just looking at the code?
#
# Choose your query with wisdom, 'cause you are going to use it next. You can also increase the time if you want to capture more tweets.

# %% [markdown]
# # Sentiment Analysis of the Tweets
#
# Change the file to your stream file in order to get the right dataset.

# %%
from unidecode import unidecode
tweets = []
text_tweets = []
fileTweets = "stream_polio_malaria.jsonl"
print fileTweets
with open(fname, 'r') as f:
    for line in f:
        tweet = json.loads(line)
        #print tweet
        try:
            aux = { "text" : unidecode(tweet['text'].replace('"','')), "language": tweet['lang'],  "query" : query, "id" : tweet['id'] }
            text_tweets.append(tweet['text'])
            tweets.append(aux)
        except:
            print 'no text', tweet
# Out:
# stream_polio_malaria.jsonl

# %%
len(tweets)
# Out:
# 2523

# %%
tweets[7]
# Out:
# {'id': 930937837867876353,
#  'language': u'en',
#  'query': ['polio', 'malaria'],
#  'text': "There are plenty of reasons to be optimistic that we can stop Alzheimer's. One of those reasons is brave patients l... https://t.co/Wf2bRnNETw"}

# %%
result = { "data" : tweets }

# %%
def parse_response(json_response):
    negative_tweets, positive_tweets = 0, 0
    negative_tweets_list, positive_tweets_list = [], [] 
    for j in json_response["data"]:
        if int(j["polarity"]) == 0:
            negative_tweets += 1
            negative_tweets_list.append(j["text"])
        elif int(j["polarity"]) == 4:
            positive_tweets += 1
            positive_tweets_list.append(j["text"])
    return negative_tweets, positive_tweets, negative_tweets_list, positive_tweets_list

# %%
import urllib2
URL_SENTIMENT140 = "http://www.sentiment140.com/api/bulkClassifyJson"
req = urllib2.Request(URL_SENTIMENT140)
req.add_header('Content-Type', 'application/json')
response = urllib2.urlopen(req, str(result))
json_response = json.loads(response.read())
negative_tweets, positive_tweets, negative_tweets_list, positive_tweets_list = parse_response(json_response)

print "Positive Tweets: " + str(positive_tweets)
for p in positive_tweets_list[:5]:
    print "\item " + p + "\n"
print "Negative Tweets: " + str(negative_tweets)
for n in negative_tweets_list[:5]:
    print "\item " + n + "\n"
# Out:
# Positive Tweets: 358
# \item RT @Lin_Manuel: Gmorning!
# Happy #GivingTuesday.
# If you don't have a dollar to give,
# you STILL have your time, your focus, your voice. Be g...
#
# \item I'm amazed by how @NandanNilekani has lent his entrepreneurial passion to philanthropy. I'm delighted to welcome hi... https://t.co/ly8PPvKz98
#
# \item I really enjoyed this conversation between our foundation CEO @SueDHellmann and Science Friday host @iraflatow. https://t.co/xRfOtBumhg
#
# \item @johngreen Congrats @johngreen. I'm excited for you and your readers - including my daughter Phoebe, who's one of your biggest fans!
#
# \item I always learn a lot from my friend @RayDalio. His new book #Principles is a remarkable look at his life and career: https://t.co/2A4EREQLYU
#
# Negative Tweets: 32
# \item "The death that didn't happen is not visible. A fascinating conversation between @Atul_Gawande and @Gladwell. https://t.co/lLprByfc0u
#
# \item I'm very disappointed with today's decision to end #DACA. Our statement: https://t.co/67YQGYtDGo
#
# \item Melinda and I are deeply saddened to learn that our friend, mentor, and advisor Sam Dryden died this morning. https://t.co/KnAhrA3Czh
#
# \item There has been incredible progress since the last Ebola outbreak. This is why we can't let up... https://t.co/BWE2PG6ZFi
#
# \item 5/ I also have one big regret: When I left school, I knew little about the world's worst inequities. Took me decades to learn.

# %% [markdown]
# ## Activity 4
#
# 1. Print a list of 5 positive and 5 negative tweets using the positive_tweets and negative_tweets list. (the responses are in the variable json_response)
# 2. Can you draw any hypotheses over why did you get this proportion of positive/negative tweets?

# %%
json_response

# %% [markdown]
# # [Extra] Time Series Analysis
# **If you have time, and wanna learn more about time series analysis, leave your stream running longer (for one hour or two, for instance) and try the code below. From this part on won't be graded!**
#
# The time series analysis evaluates the tweets over time, giving us an idea about how many tweets were collected every minute. Remember to change the name of fname in case you changed your query.

# %%
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import pandas as pd
import numpy as np
import pickle

# %%
fname = 'stream_Ajax_football.jsonl'

with open(fname, 'r') as f:
    all_dates = []
    for line in f:
        tweet = json.loads(line)
        all_dates.append(tweet.get('created_at'))

# %%
ones = np.ones(len(all_dates))
idx = pd.DatetimeIndex(all_dates)
# the actual series (at series of 1s for the moment)
my_series = pd.Series(ones, index=idx)

# %%
# Resampling / bucketing into 1-minute buckets
per_minute = my_series.resample('1Min').sum().fillna(0)
print(my_series.head())
print(per_minute.head(30))

# %%
fig, ax = plt.subplots()
ax.grid(True)
ax.set_title("Tweet Frequencies")

hours = mdates.MinuteLocator(interval=1)
date_formatter = mdates.DateFormatter('%H:%M')

datemin = datetime(2016, 11, 12, 18, 37)
datemax = datetime(2016, 11, 12, 18, 47)

ax.xaxis.set_major_locator(hours)
ax.xaxis.set_major_formatter(date_formatter)
ax.set_xlim(datemin, datemax)
max_freq = per_minute.max()
ax.set_ylim(0, max_freq+100)
ax.plot(per_minute.index, per_minute)

#ax.xticks(rotation=90)

plt.savefig('tweet_time_series.png')

# %% [markdown]
# # [Extra] Users, Followers and Communities
#
# This section is not part of the assignment. Just read and play with it if you wanna learn a little bit of how to get users that are followers or friends of a certain node.

# %%
client = get_twitter_client()
profile = client.get_user(screen_name='ericinlinux')
print(json.dumps(profile._json, indent=4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-15b658dff8e4> in <module>()
# ----> 1 client = get_twitter_client()
#       2 profile = client.get_user(screen_name='ericinlinux')
#       3 print(json.dumps(profile._json, indent=4))
#
# NameError: name 'get_twitter_client' is not defined

# %%
import time
import math

MAX_FRIENDS = 15000

def paginate(items, n):
    """Generate n-sized chunks from items"""
    for i in range(0, len(items), n):
        yield items[i:i+n]

# %%
screen_name = 'ericinlinux'

client = get_twitter_client()
dirname = "users/{}".format(screen_name)
max_pages = math.ceil(MAX_FRIENDS / 5000)

try:
    
    os.makedirs(dirname)
except OSError:
    print("Directory {} already exists".format(dirname))
except Exception as e:
    print("Error while creating directory {}".format(dirname))
    print(e)
    sys.exit(1)

# %%
# get followers for a given user
fname = "users/{}/followers.jsonl".format(screen_name)
with open(fname, 'w') as f:
    for followers in Cursor(client.followers_ids, screen_name=screen_name).pages(max_pages):
        for chunk in paginate(followers, 100):
            users = client.lookup_users(user_ids=chunk)
            for user in users:
                f.write(json.dumps(user._json)+"\n")
        if len(followers) == 5000:
            print("More results available. Sleeping for 60 seconds to avoid rate limit")
            time.sleep(60)

# get friends for a given user
fname = "users/{}/friends.jsonl".format(screen_name)
with open(fname, 'w') as f:
    for friends in Cursor(client.friends_ids, screen_name=screen_name).pages(max_pages):
        for chunk in paginate(friends, 100):
            users = client.lookup_users(user_ids=chunk)
            for user in users:
                f.write(json.dumps(user._json)+"\n")
        if len(friends) == 5000:
            print("More results available. Sleeping for 60 seconds to avoid rate limit")
            time.sleep(60)

# get user's profile
fname = "users/{}/user_profile.json".format(screen_name)
with open(fname, 'w') as f:
    profile = client.get_user(screen_name=screen_name)
    f.write(json.dumps(profile._json, indent=4))

# %% [markdown]
# You can see a folder called users in the same directory as this file with the json files there. You can try to extract information about the JSON files and get more from here.
#
# Have fun!
